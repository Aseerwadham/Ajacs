# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 1000
# python
# [1, 2, 3, 4]
# (10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a,end=",")
print(b)
print(c)
print(d)
print(e)
# Out:
# 1000,python
# [1, 2, 3, 4]
# (10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a)
print(b)
print(c,end=",")
print(d)
print(e)
# Out:
# 1000
# python
# [1, 2, 3, 4],(10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a)
print(b)
print(c,end="////")
print(d)
print(e)
# Out:
# 1000
# python
# [1, 2, 3, 4]////(10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a)
print(b)
print(c,end="kdbhfuhd")
print(d)
print(e)
# Out:
# 1000
# python
# [1, 2, 3, 4]kdbhfuhd(10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a)
print(b)
print(c,end=",")
print(d)
print(e)
# Out:
# 1000
# python
# [1, 2, 3, 4],(10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 1000
# python
# [1, 2, 3, 4]
# (10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a)
print(b)
print(c)
print(d)
print(e, end="\n")
# Out:
# 1000
# python
# [1, 2, 3, 4]
# (10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a, end="\n")
print(b)
print(c)
print(d)
print(e)
# Out:
# 1000
# python
# [1, 2, 3, 4]
# (10, 20, 30, 40)
# {16, 18, 20, 12}

# %%
a=1000
b="python"
c=[1,2,3,4]
d=(10,20,30,40)
e={20,16,12,18}
print(a, "\n")
print(b)
print(c)
print(d)
print(e)
# Out:
# 1000
#
# python
# [1, 2, 3, 4]
# (10, 20, 30, 40)
# {16, 18, 20, 12}
