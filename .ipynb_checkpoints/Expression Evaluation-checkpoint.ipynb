# %%
s=10+20
print(s)
# Out:
# 30

# %%
s=10+20+30
print(s)
# Out:
# 60

# %%
s=10+20/5*4
s
# Out:
# 26.0

# %%
s=(10+20)/5*4
s
# Out:
# 24.0

# %%
s=1000/200/5/2
s
# Out:
# 0.5

# %%
s=2/5/200/1000
s
# Out:
# 2e-06

# %%
s=(1000/(200/(5/2)))
s
# Out:
# 12.5
