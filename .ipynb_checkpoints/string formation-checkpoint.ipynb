# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
number_of_sales=input("Enter number_of_sales: ")
profit=input("Enter profit: ")
s="The "+customer_name+" is a very good customer, bought "+number_of_sales+" sales orders from our portal. we got "+profit+" profit because of "+customer_name+"."
print(s)
# Out:
# Enter customer_name:  Asee
# Enter number_of_sales:  10
# Enter profit:  20
# The Asee is a very good customer, bought 10 sales orders from our portal. we got 20 profit because of Asee.

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
number_of_sales=input("Enter number_of_sales: ")
profit=input("Enter profit: ")
s="The "+customer_name+" is a very good customer, bought "+number_of_sales+" sales orders from our portal. we got "+profit+" profit because of "+customer_name+"."
print(s)
# Out:
# Enter customer_name:  Mahesh
# Enter number_of_sales:  10
# Enter profit:  20
# The Mahesh is a very good customer, bought 10 sales orders from our portal. we got 20 profit because of Mahesh.

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
number_of_sales=input("Enter number_of_sales: ")
profit=input("Enter profit: ")
s="The "+customer_name+" is a very good customer, bought "+number_of_sales+" sales orders from our portal. we got "+profit+" profit because of "+customer_name+"."
print(s)
# Out:
# Enter customer_name:  satish
# Enter number_of_sales:  10
# Enter profit:  15
# The satish is a very good customer, bought 10 sales orders from our portal. we got 15 profit because of satish.

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
number_of_sales=input("Enter number_of_sales: ")
profit=input("Enter profit: ")
s="The "+customer_name+" is a very good customer, bought "+number_of_sales+" sales orders from our portal. we got "+profit+" profit because of "+customer_name+"."
print(s)
# Out:
# Enter customer_name:  sireesh
# Enter number_of_sales:  26
# Enter profit:  12
# The sireesh is a very good customer, bought 26 sales orders from our portal. we got 12 profit because of sireesh.

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
number_of_sales=input("Enter number_of_sales: ")
profit=input("Enter profit: ")
s="The "+customer_name+" is a very good customer, bought "+number_of_sales+\
" sales orders from our portal. we got "+profit+" profit because of "+customer_name+"."
print(s)
# Out:
# Enter customer_name:  Narendra
# Enter number_of_sales:  1000
# Enter profit:  50000
# The Narendra is a very good customer, bought 1000 sales orders from our portal. we got 50000 profit because of Narendra.

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
print("The {customer_name} is a very good customer, bought ")
# Out:
# Enter customer_name:  Anil
# The {customer_name} is a very good customer, bought

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
print(f"The {customer_name} is a very good customer, bought ")### template string: f string
# Out:
# Enter customer_name:  Anil
# The Anil is a very good customer, bought

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
number_of_sales=input("Enter number_of_sales: ")
profit=input("Enter profit: ")
print(f"The {customer_name} is a very good customer, bought {number_of_sales} sales orders from our portal. we got {profit} profit because of {customer_name}.")### template string: f string
# Out:
# Enter customer_name:  Anil
# Enter number_of_sales:  100
# Enter profit:  500
# The Anil is a very good customer, bought 100 sales orders from our portal. we got 500 profit because of Anil.

# %%
a=1000
print("The product Cost:"+a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 a=1000
# ----> 2 print("The product Cost:"+a)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# The Anil kumar is a very good customer, bought 3045 sales orders from our portal. we got 20000 profit because of Anil kumar.
customer_name=input("Enter customer_name: ")
number_of_sales=input("Enter number_of_sales: ")
profit=input("Enter profit: ")
print(f"The {customer_name} is a very good customer, bought {number_of_sales} sales orders from our portal. we got {profit} profit because of {customer_name}.")### template string: f string
# Out:
# Enter customer_name:  Suresh
# Enter number_of_sales:  50
# Enter profit:  2000
# The Suresh is a very good customer, bought 50 sales orders from our portal. we got 2000 profit because of Suresh.

# %%
a=1000
print("The product Cost:"+str(a))
# Out:
# The product Cost:1000

# %%
a=1000
print("The product Cost:{a})
# Out:
#   Cell In[26], line 2
#     print("The product Cost:{a})
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
a=1000
print(f"The product Cost:{a}")
# Out:
# The product Cost:1000

# %%
cost=123.45678
print(f"The product Cost:{int(cost)}")
# Out:
# The product Cost:123

# %%
cost=123.45678
print(f"The product Cost:{cost: d}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 cost=123.45678
# ----> 2 print(f"The product Cost:{cost: d}")
#
# ValueError: Unknown format code 'd' for object of type 'float'

# %%
cost=123.45678
print(f"The product Cost:{cost: f}")
# Out:
# The product Cost: 123.456780

# %%
cost=123.4567856662664
print(f"The product Cost:{cost: f}")
# Out:
# The product Cost: 123.456786

# %%
cost=123.4567856662664
print(f"The product Cost:{cost: 2f}")
# Out:
# The product Cost: 123.456786

# %%
cost=123.4567856662664
print(f"The product Cost:{cost: .2f}")
# Out:
# The product Cost: 123.46

# %%
cost=123.4567856662664
print(f"The product Cost:{cost: .4f}")
# Out:
# The product Cost: 123.4568

# %%
cost=123.4567856662664
print(f"The product Cost:{cost: .0f}")
# Out:
# The product Cost: 123

# %%
#format specifiers: %s, %d, %r, %f

# %%
cost=123.4567856662664
print(f"The product Cost: %s")
# Out:
# The product Cost: %s

# %%
cost=123.4567856662664
print("The product Cost: %s", cost)
# Out:
# The product Cost: %s 123.4567856662664

# %%
cost=123.4567856662664
print("The product Cost: %s" %cost)
# Out:
# The product Cost: 123.4567856662664

# %%
cost=123.4567856662664
print("The product Cost: %f" %cost)
# Out:
# The product Cost: 123.456786

# %%
cost=123.4567856662664
print("The product Cost: %d" %cost)
# Out:
# The product Cost: 123

# %%
cost=123.4567856662664
print("The product Cost: %r" %cost)
# Out:
# The product Cost: 123.4567856662664

# %%
#special
print("bkbkjc \n ndjdnwehiew \t nwnefjefew")
# Out:
# bkbkjc
#  ndjdnwehiew 	 nwnefjefew

# %%
#special
print("bkbkj\nndjdnwehiew\tnwnefjefew")
# Out:
# bkbkj
# ndjdnwehiew	nwnefjefew

# %%
#special
print("bkbkj\\nndjdnwehiew\\tnwnefjefew")
# Out:
# bkbkj\nndjdnwehiew\tnwnefjefew

# %%
#special
print("bkbkj"\n"ndjdnwehiew"\t"nwnefjefew")
# Out:
#   Cell In[80], line 2
#     print("bkbkj"\n"ndjdnwehiew"\t"nwnefjefew")
#                   ^
# SyntaxError: unexpected character after line continuation character

# %%
#special
print("bkbkj\nndjdnwehiew\tnwnefjefew")
# Out:
# bkbkj
# ndjdnwehiew	nwnefjefew

# %%
#special
print(r"bkbkj\nndjdnwehiew\tnwnefjefew") #python considered as raw string
# Out:
# bkbkj\nndjdnwehiew\tnwnefjefew

# %%
cost=123.45
discount=34
total=345
name"APPLE"
print("the product %s, cost:%s, discount:%s"%(name, discount, total,cost) )
# Out:
#   Cell In[86], line 4
#     name"APPLE"
#         ^
# SyntaxError: invalid syntax

# %%
cost=123.45
discount=34
total=345
name="APPLE"
print("the product %s, name%s, cost:%s, total:%s, discount:%s"%(name, cost, total, discount) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 5
#       3 total=345
#       4 name="APPLE"
# ----> 5 print("the product %s, name%s, cost:%s, total:%s, discount:%s"%(name, cost, total, discount) )
#
# TypeError: not enough arguments for format string
