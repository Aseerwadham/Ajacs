# %%
f=open('data.txt')

# %%
import data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import data
#
# ModuleNotFoundError: No module named 'data'

# %%
print(dir(f))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
f=open('data.txt')

# %%
data=f.read()

# %%
print(data)
# Out:
# name,age,sal
# Asee,27,234567
# Satya,26,123456
# Ravi,25,45678

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
print(dir(f))
# Out:
# ['_CHUNK_SIZE', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '_checkClosed', '_checkReadable', '_checkSeekable', '_checkWritable', '_finalizing', 'buffer', 'close', 'closed', 'detach', 'encoding', 'errors', 'fileno', 'flush', 'isatty', 'line_buffering', 'mode', 'name', 'newlines', 'read', 'readable', 'readline', 'readlines', 'reconfigure', 'seek', 'seekable', 'tell', 'truncate', 'writable', 'write', 'write_through', 'writelines']

# %%
data1=f.read()

# %%
print(data1)

# %%
f.close()

# %%
f=open('data.txt')

# %%
print(f.tell())
# Out:
# 0

# %%
data=f.read()

# %%
print(data)
# Out:
# name,age,sal
# Asee,27,234567
# Satya,26,123456
# Ravi,25,45678

# %%
print(f.tell())
# Out:
# 60

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.tell())
# Out:
# 0

# %%
f.close()

# %%
f=open('data.txt')
print(f.tell())
data=f.read(12)
print(data)
print(f.tell())
# Out:
# 0
# name,age,sal
# 12

# %%
data1=f.read(12)
print(data1)
print(f.tell())
# Out:
# Asee,27,234
# 25

# %%
data2=f.read(12)
print(data2)
print(f.tell())
# Out:
# 567
# Satya,26
# 38

# %%
data3=f.read(12)
print(data3)
print(f.tell())
# Out:
# ,123456
# Ravi
# 51

# %%
data3=f.read(12)
print(data3)
print(f.tell())
# Out:
# ,25,45678
# 60

# %%
data3=f.read(12)
print(data3)
print(f.tell())
# Out:
# 60

# %%
f.close()

# %%
f=open('data.txt')
data=f.read()
print(data)
# Out:
# name,age,sal
# Asee,27,234567
# Satya,26,123456
# Ravi,25,45678

# %%
f.close()

# %%
f=open('data.txt')
for row in f:
    print(row)
f.close()
# Out:
# name,age,sal
#
# Asee,27,234567
#
# Satya,26,123456
#
# Ravi,25,45678

# %%
f=open('data.txt')
for row in f:
    print(row)
    print("*"*20)
f.close()
# Out:
# name,age,sal
#
# ********************
# Asee,27,234567
#
# ********************
# Satya,26,123456
#
# ********************
# Ravi,25,45678
# ********************

# %%
f=open('data.txt')
for row in f:
    print(row)
    print(row.split(","))
    print("*"*25)
f.close()
# Out:
# name,age,sal
#
# ['name', 'age', 'sal\n']
# *************************
# Asee,27,234567
#
# ['Asee', '27', '234567\n']
# *************************
# Satya,26,123456
#
# ['Satya', '26', '123456\n']
# *************************
# Ravi,25,45678
# ['Ravi', '25', '45678']
# *************************

# %%
f=open('data.txt')
for row in f:
    print(row.split(",")[-1])
    print("*"*20)
f.close()
# Out:
# sal
#
# ********************
# 234567
#
# ********************
# 123456
#
# ********************
# 45678
# ********************

# %%
f=open('data.txt')
for row in f:
    print(row.split(",")[-1].strip())
    print("*"*10)
f.close()
# Out:
# sal
# **********
# 234567
# **********
# 123456
# **********
# 45678
# **********

# %%
f=open('data.txt')
sals=[]
for row in f:
    sals.append(row.split(",")[-1].strip())
f.close()
print(sals)
# Out:
# ['sal', '234567', '123456', '45678']

# %%
f=open('data.txt')
first_line=f.readline()#It reads the first line, then iteration will start from second column
sals=[]
for row in f:
    sals.append(int(row.split(",")[-1].strip()))
f.close()
print(sals)
print(sum(sals))
# Out:
# [234567, 123456, 45678]
# 403701

# %%
f=open('data.txt')
data=f.readlines() # All data stores like an elements in a string
print(data)
# Out:
# ['name,age,sal\n', 'Asee,27,234567\n', 'Satya,26,123456\n', 'Ravi,25,45678']

# %%
#What is your ram size? 8gb., then create 10gb bigfile

# %%
f=open("BIGFILE.txt","w")

# %%
f.write("name,age,sal\n")
f.write("Asee,27,234589\n")
f.write("satya,26,123458\n")
f.write("sunny,8,10200\n")
# Out:
# 14

# %%
len("Asee,27,234589\n")
# Out:
# 15

# %%
f.flush()

# %%
f.write("Ravi,25,45789\n")
# Out:
# 14

# %%
f.flush()

# %%
f.write("raji,24,12345\n")
# Out:
# 14

# %%
f.close()

# %%
f.write("raj,27,123454656\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 f.write("raj,27,123454656\n")
#
# ValueError: I/O operation on closed file.

# %%
import faker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 import faker
#
# ModuleNotFoundError: No module named 'faker'

# %%
from faker import Faker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 from faker import Faker
#
# ModuleNotFoundError: No module named 'faker'

# %%
import faker

# %%
from faker import Faker

# %%
faker = Faker()

# %%
faker.name()
# Out:
# 'Paul Black'

# %%
from random import randint

# %%
print(dir(randint))
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__func__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__self__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
randint(15,45)
# Out:
# 17

# %%
randint(15,45)
# Out:
# 38

# %%
randint(15,45)
# Out:
# 22

# %%
randint(15,45)
# Out:
# 28

# %%
from faker import Faker
from random import randint
fake = Faker()
f=open("BIGFILE.txt","w")
for i in range(481457280):
    row = f"{fake.name()},{randint(23,60)},{randint(1000,9900000)}\n"
    f.write(row)
    f.flush()
f.close()

# %%
f=open("BIGFILE.txt")
first_line=f.readline()
sals=[]
for row in f:
    sals.append(int(row.split(",")[-1].strip()))
f.close()
print(sum(sals))

# %%
f=open("BIGFILE.txt")
first_line=f.readline()
sals=[]
for row in f:
    sals.append(int(row.split(",")[-1].strip()))
names=sals.sort[-1:-11:-1]
f.close()
print(names)
