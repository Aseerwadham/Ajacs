# %%
##Important topic

# %%
s="abcdefghijkl"
print(s[0])
# Out:
# a

# %%
s="abcdefghijkl"
print(s[1])
# Out:
# b

# %%
s="abcdefghijkl"
print(s[-1])
# Out:
# l

# %%
s="abcdefghijkl"
print(s[-12])
# Out:
# a

# %%
print(s[-12])
print(s[0]) #every element has two indices
# Out:
# a
# a

# %%
s="abcdefghijkl"
print(s[0],s[1],s[2])
# Out:
# a b c

# %%
s="abcdefghijkl"
print(s[0]+s[1]+s[2])
# Out:
# abc

# %%
s="abcdefghijkl"
print(s[0:3]) #default step value 1
# Out:
# abc

# %%
s="abcdefghijkl"
print(s[5:12])
# Out:
# fghijkl

# %%
s="abcdefghijkl"
print(s[16]) # indexing
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 s="abcdefghijkl"
# ----> 2 print(s[16])
#
# IndexError: string index out of range

# %%
s="abcdefghijkl"
print(s[2:18]) ##Slicing
# Out:
# cdefghijkl

# %%
s="abcdefghijkl"
print(s[2:10:-1])

# %%
s="abcdefghijkl"
print(s[2:-10:-1])

# %%
s="abcdefghijkl"
print(s[2:50:])
# Out:
# cdefghijkl

# %%
print(s[2:-10:-1])

# %%
s="abcdefghijkl"
print(s[2:-11:-1])
# Out:
# c

# %%
s="abcdefghijkl"
print(s[-2:-11:-1])
# Out:
# kjihgfedc

# %%
s="abcdefghijkl"
print(s[-2:-11:1])

# %%
s="abcdefghijkl"
print(s[2:11:2])
# Out:
# cegik

# %%
s="abcdefghijkl"
print(s[2:-11:-2])
# Out:
# c

# %%
s="abcdefghijkl"
print(s[7:-15:-3])
# Out:
# heb

# %%
s="abcdefghijkl"
print(s[:3:-1])
# Out:
# lkjihgfe

# %%
s="abcdefghijkl"
print(s[:3])
# Out:
# abc

# %%
s="abcdefghijkl"
print(s[:-3:-1])
# Out:
# lk

# %%
s="abcdefghijkl"
print(s[11:-1])

# %%
s="abcdefghijkl"
print(s[10:-1:2])
# Out:
# k

# %%
s="abcdefghijkl"
print(s[9:-1:2])
# Out:
# j

# %%
s="abcdefghijkl"
print(s[9:-1])
# Out:
# jk

# %%
s="abcdefghijkl"
print(s[10:-1])
# Out:
# k

# %%
l=["apple","orange","grape","mango","papaya"]
print(l[:2])
# Out:
# ['apple', 'orange']

# %%
l=["apple","orange","grape","mango","papapya"]
print(l[:2:-1])
# Out:
# ['papapya', 'mango']
