# %%
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pymysql
#
# ModuleNotFoundError: No module named 'pymysql'

# %%
import pymysql

# %%
conn = pymysql.connect?
# Out:
# Init signature:
# pymysql.connect(
#     *,
#     user=None,
#     password='',
#     host=None,
#     database=None,
#     unix_socket=None,
#     port=0,
#     charset='',
#     collation=None,
#     sql_mode=None,
#     read_default_file=None,
#     conv=None,
#     use_unicode=True,
#     client_flag=0,
#     cursorclass=<class 'pymysql.cursors.Cursor'>,
#     init_command=None,
#     connect_timeout=10,
#     read_default_group=None,
#     autocommit=False,
#     local_infile=False,
#     max_allowed_packet=16777216,
#     defer_connect=False,
#     auth_plugin_map=None,
#     read_timeout=None,
#     write_timeout=None,
#     bind_address=None,
#     binary_prefix=False,
#     program_name=None,
#     server_public_key=None,
#     ssl=None,
#     ssl_ca=None,
#     ssl_cert=None,
#     ssl_disabled=None,
#     ssl_key=None,
#     ssl_key_password=None,
#     ssl_verify_cert=None,
#     ssl_verify_identity=None,
#     compress=None,
#     named_pipe=None,
#     passwd=None,
# ...

# %%
conn = pymysql.connect(host="localhost", user="root",password="root@1234",database="python")

# %%
cur = conn.cursor()  # to interact with db using cur as a buffer space

# %%
print(cur)

# %%
cur.execute("") ## it will execute whatever querry u are passed
