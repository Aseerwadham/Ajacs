# %%
print("started")
a=1000
b=2000
print("a is big")
print("b is big")
print("ended")
# Out:
# started
# a is big
# b is big
# ended

# %%
print("started")
a=1000
b=2000
if True:
    print("a is big")
else: 
    print("b is big")
print("ended")
# Out:
# started
# a is big
# ended

# %%
print("started")
a=1000
b=2000
if False:
    print("a is big")
else: 
    print("b is big")
print("ended")
# Out:
# started
# b is big
# ended

# %%
print("started")
a=1000
b=2000
if False:
    print("b is big")
else: 
    print("a is big")
print("ended")
# Out:
# started
# a is big
# ended

# %%
print("started")
a=1000
b=2000
if False:
    print("HELLO")
    print("b is big")
else: 
    print("HI")
    print("a is big")
print("ended")
# Out:
# started
# HI
# a is big
# ended

# %%
print("started")
a=1000
b=2000
if bool(20):
    print("HELLO")
    print("b is big")
else: 
    print("HI")
    print("a is big")
print("ended")
# Out:
# started
# HELLO
# b is big
# ended

# %%
print("started")
a=1000
b=2000
if bool("python"):
    print("HELLO")
    print("b is big")
else: 
    print("HI")
    print("a is big")
print("ended")
# Out:
# started
# HELLO
# b is big
# ended

# %%
print("started")
a=0
if bool(a):
    print("HELLO")
    print("b is big")
else: 
    print("HI")
    print("a is big")
print("ended")
# Out:
# started
# HI
# a is big
# ended

# %%
print("started")
a=1234
if bool(a):
    print("HELLO")
    print("b is big")
else: 
    print("HI")
    print("a is big")
print("ended")
# Out:
# started
# HELLO
# b is big
# ended

# %%
a=1000
b=2000
print("a is big")
print("b is big")
# Out:
# a is big
# b is big

# %%
print("started")
a=0
if a: #bool(a)
    print("HELLO")
    print("b is big")
else: 
    print("HI")
    print("a is big")
print("ended")
# Out:
# started
# HI
# a is big
# ended

# %%
if 19:
    print("hello")
print("hi")
# Out:
# hello
# hi

# %%
if 19:
    print("hello")
else:
    print("hi")
# Out:
# hello

# %%
if 0:
    print("hello")
else:
    print("hi")
# Out:
# hi

# %%
value = input("enter a value: ")
print(len(value))
# Out:
# enter a value:  asee
# 4

# %%
value = input("enter a value: ")
print(len(value))
# Out:
# enter a value:
# 0

# %%
value = input("enter a value: ")
print(len(value))
# Out:
# enter a value:  satya
# 5

# %%
value = ''
print(len(value))
# Out:
# 0

# %%
value = input("enter a value: ")
print(type(value))
# Out:
# enter a value:  20
# <class 'str'>

# %%
value = float(input("enter a value: "))
print(type(value))
# Out:
# enter a value:  12
# <class 'float'>

# %%
value = float(input("enter a value: "))
print(type(value))
# Out:
# enter a value:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 value = float(input("enter a value: "))
#       2 print(type(value))
#
# ValueError: could not convert string to float: ''

# %%
#value1, value2, value1+value2

# %%
value1 = input("enter a value1: ")
print(value1)
value2 = input("enter a value2: ")
print(value2)
print(value1+value2)
# Out:
# enter a value1:  15
# 15
# enter a value2:  14
# 14

# %%
value1 = input("enter a value1: ")
print(value1)
value2 = input("enter a value2: ")
print(value2)
print(value1+value2)
# Out:
# enter a value1:  12
# 12
# enter a value2:  13
# 13
# 1213

# %%
value1 = input("enter a value1: ")
print(value1)
value2 = input("enter a value2: ")
print(value2)
print(value1+value2)
# Out:
# enter a value1:  5
# 5
# enter a value2:
# 5

# %%
int("")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 int("")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
value1 = input("enter a value1: ")
print(value1)
value2 = input("enter a value2: ")
print(value2)
if value2 =="":
    value2 = 0
print(value1+value2)
# Out:
# enter a value1:  12
# 12
# enter a value2:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 7
#       5 if value2 =="":
#       6     value2 = 0
# ----> 7 print(value1+value2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#value1, value2, value1+value2
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
print(value1+value2)
# Out:
# enter a value1:  12
# enter a value2:  12
# 1212

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
print(value1+value2)
# Out:
# enter a value1:  2
# enter a value2:
# 2

# %%
value1 = float(input("enter a value1: "))
value2 = float(input("enter a value2: "))
print(value1+value2)
# Out:
# enter a value1:  12
# enter a value2:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 2
#       1 value1 = float(input("enter a value1: "))
# ----> 2 value2 = float(input("enter a value2: "))
#       3 print(value1+value2)
#
# ValueError: could not convert string to float: ''

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
if value1=="":
    value1=0
else:
    value1 = float(value1)
if value2=="":
    value2=0
else:
    value2 = float(value2)
print(value1+value2)
# Out:
# enter a value1:  12
# enter a value2:  13
# 25.0

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
if value1=="": ##true
    value1=0
else:
    value1 = float(value1)
if value2=="": ##false
    value2=0
else:
    value2 = float(value2)
print(value1+value2)
# Out:
# enter a value1:
# enter a value2:  34
# 34.0

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
if value1=="": ##false
    value1=0
else:
    value1 = float(value1)
if value2=="": ##true
    value2=0
else:
    value2 = float(value2)
print(value1+value2)
# Out:
# enter a value1:  12
# enter a value2:
# 12.0

# %%
bool("")
# Out:
# False

# %%
bool("1321")
# Out:
# True

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
if value1:
    value1 = float(value1)
else:
    value1=0
if value2: 
    value2 = float(value2)
else:
    value2=0
print(value1+value2)
# Out:
# enter a value1:
# enter a value2:
# 0

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
if value1:
    value1 = float(value1)
else:
    value1=0
if value2: 
    value2 = float(value2)
else:
    value2=0
print(value1+value2)
# Out:
# enter a value1:  12
# enter a value2:  5
# 17.0

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
if value1:
    value1 = float(value1)
else:
    value1=0
if value2: 
    value2 = float(value2)
else:
    value2=0
print(value1+value2)
# Out:
# enter a value1:  5
# enter a value2:
# 5.0

# %%
value1 = input("enter a value1: ")
value2 = input("enter a value2: ")
if value1:
    value1 = float(value1)
else:
    value1=0
if value2: 
    value2 = float(value2)
else:
    value2=0
print(f"value1={value1}, value2={value2}")
print(value1+value2)
# Out:
# enter a value1:  11
# enter a value2:  11
# value1=11.0, value2=11.0
# 22.0

# %%
"1"==1
# Out:
# False

# %%
a=1000
b=2000
print("1.add\n2.sub\n3.mul\n4.division")
opt = input("Enter an option: ")
if opt == "1":
    print(a+b)
if opt == "2":
    print(a-b)
if opt == "3":
    print(a*b)
if opt == "4":
    print(a/b)
print("Thank you!!")
# Out:
# 1.add
# 2.sub
# 3.mul
# 4.division
# Enter an option:  2
# -1000
# Thank you!!

# %%
a=1000
b=2000
print("1.add\n2.sub\n3.mul\n4.division")
opt = input("Enter an option: ")
if opt == "1":
    print(a+b)
if opt == "2":
    print(a-b)
if opt == "3":
    print(a*b)
if opt == "4":
    print(a/b)
print("Thank you!!")
# Out:
# 1.add
# 2.sub
# 3.mul
# 4.division
# Enter an option:  6
# Thank you!!

# %%
a=1000
b=2000
print("1.add\n2.sub\n3.mul\n4.division")
opt = input("Enter an option: ")
if opt == "1":
    print(a+b)
if opt == "2":
    print(a-b)
if opt == "3":
    print(a*b)
if opt == "4":
    print(a/b)
else:
    print("Enter valid option")
print("Thank you!!")
# Out:
# 1.add
# 2.sub
# 3.mul
# 4.division
# Enter an option:  5
# Enter valid option
# Thank you!!

# %%
a=1000
b=2000
print("1.add\n2.sub\n3.mul\n4.division")
opt = input("Enter an option: ")
if opt == "1": # "4" == "1" false
    print(a+b)
if opt == "2": # "4" == "2" false
    print(a-b)
if opt == "3": # "4" == "3" false
    print(a*b)
if opt == "4": # "4" == "4" true
    print(a/b)
else:
    print("Enter valid option")
print("Thank you!!")
# Out:
# 1.add
# 2.sub
# 3.mul
# 4.division
# Enter an option:  4
# 0.5
# Thank you!!

# %%
a=1000
b=2000
print("1.add\n2.sub\n3.mul\n4.division")
opt = input("Enter an option: ")
if opt == "1": # "3" == "1" false
    print(a+b)
if opt == "2": # "3" == "2" false
    print(a-b)
if opt == "3": # "3" == "3" true
    print(a*b)
if opt == "4": # "3" == "4" false
    print(a/b)
else:
    print("Enter valid option") ## but here else block is for opt 4 only, then why its printed in result even its false; To Overcome 'elif' is used.
print("Thank you!!")
# Out:
# 1.add
# 2.sub
# 3.mul
# 4.division
# Enter an option:  3
# 2000000
# Enter valid option
# Thank you!!

# %%
#ELIF:
a=1000
b=2000
print("1.add\n2.sub\n3.mul\n4.division")
opt = input("Enter an option: ")
if opt == "1": # "2" == "1" false
    print(a+b)
elif opt == "2": # "2" == "2" false
    print(a-b)
elif opt == "3": # "2"== "3" false
    print(a*b)
elif opt == "4": # "2" == "4" true
    print(a/b)
else:
    print("Enter valid option")
print("Thank you!!")
# Out:
# 1.add
# 2.sub
# 3.mul
# 4.division
# Enter an option:  2
# -1000
# Thank you!!

# %%
#ELIF:
a=1000
b=2000
print("1.add\n2.sub\n3.mul\n4.division")
opt = input("Enter an option: ")
if opt == "1": 
    print(a+b)
elif opt == "2": 
    print(a-b)
elif opt == "3": 
    print(a*b)
elif opt == "4": 
    print(a/b)
else:
    print("Enter valid option")
print("Thank you!!")
# Out:
# 1.add
# 2.sub
# 3.mul
# 4.division
# Enter an option:  5
# Enter valid option
# Thank you!!

# %%
# take a number from the user and check whether its even or odd
number=input("Enter number: ")
number=float(number)
if number%2 == 0:
    print("EVEN")
else:
    print("ODD")
# Out:
# Enter number:  5
# ODD

# %%
# take a number from the user and check whether its even or odd
number=input("Enter number: ")
number=float(number)
if number%2 == 0:
    print("EVEN")
else:
    print("ODD")
# Out:
# Enter number:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 # take a number from the user and check whether its even or odd
#       2 number=input("Enter number: ")
# ----> 3 number=float(number)
#       4 if number%2 == 0:
#       5     print("EVEN")
#
# ValueError: could not convert string to float: ''

# %%
# take a number from the user and check whether its even or odd
number=input("Enter number: ") #24
if number: #bool(24)==true
    number=float(number)
    if number%2 == 0: #24%2 ==0 true
        print("EVEN")
    else:
        print("ODD")
else:
    print("Enter a valid number")
# Out:
# Enter number:  24
# EVEN

# %%
# take a number from the user and check whether its even or odd
number=input("Enter number: ") #24
if number: #bool(24)==true
    number=float(number)
    if number%2 == 0: #24%2 ==0 true
        print("EVEN")
    else:
        print("ODD")
else:
    print("Enter a valid number")
# Out:
# Enter number:  7
# ODD

# %%
# take a number from the user and check whether its even or odd
number=input("Enter number: ") #24
if number: #bool(24)==true
    number=float(number)
    if number%2 == 0: #24%2 ==0 true
        print("EVEN")
    else:
        print("ODD")
else:
    print("Enter a valid number")
# Out:
# Enter number:
# Enter a valid number

# %%
bool("")
# Out:
# False

# %%
bool("0")
# Out:
# True

# %%
# take a number from the user and check whether its even or odd
number=input("Enter number: ") #""
if number: #bool("")==false
    number=float(number)
    if number%2 == 0: 
        print("EVEN")
    else:
        print("ODD")
else:
    print("Enter a valid number")

# %%
number = 12
if number%2==0:
    print("EVEN")
else:
    print("ODD")
# Out:
# EVEN

# %%
number = 12
print("EVEN" if number%2==0 else "ODD")
# Out:
# EVEN

# %%
all([True, True, True])
# Out:
# True

# %%
all([True, False, True])
# Out:
# False

# %%
any([True, True, True])
# Out:
# True

# %%
any([True, False, False])
# Out:
# True

# %%
print("1.Men\n2.Women")
gender = input("Enter gender:")
age = input("Enter an age:")
age=float(age)
if gender=="1":
    if age>=5:
        print("He can got to movie.")
    if age>=18:
        print("He can apply for vote.")
    if age>=23:
        print("He can get marriged.")
    if age>=18 and age<=32:
        print("He can apply for govt jobs.")
    if age>=18 and age<=60:
        print("he can apply for driving license")
else:
    if age>=7:
        print("He can got to movie.")
    if age>=18:
        print("He can apply for vote.")
    if age>=21:
        print("He can get marriged.")
    if age>=18 and age<=34:
        print("He can apply for govt jobs.")
    if age>=18 and age<=60:
        print("he can apply for driving license")
# Out:
# 1.Men
# 2.Women
# Enter gender: 1
# Enter an age: 26
# He can got to movie.
# He can apply for vote.
# He can get marriged.
# He can apply for govt jobs.
# he can apply for driving license

# %%
print("1.Men\n2.Women")
gender = input("Enter gender:")
age = input("Enter an age:")
age=float(age)
if gender=="1":
    if age>=5:
        print("He can got to movie.")
    if age>=18:
        print("He can apply for vote.")
    if age>=23:
        print("He can get marriged.")
    if age>=18 and age<=32:
        print("He can apply for govt jobs.")
    if age>=18 and age<=60:
        print("he can apply for driving license")
else:
    if age>=7:
        print("she can got to movie.")
    if age>=18:
        print("she can apply for vote.")
    if age>=21:
        print("she can get marriged.")
    if age>=18 and age<=34:
        print("she can apply for govt jobs.")
    if age>=18 and age<=60:
        print("she can apply for driving license")
# Out:
# 1.Men
# 2.Women
# Enter gender: 2
# Enter an age: 24
# she can got to movie.
# she can apply for vote.
# she can get marriged.
# she can apply for govt jobs.
# she can apply for driving license

# %%
number = 13
k= any("EVEN" if number%2==0  else "ODD")
print(k)
# Out:
# True

# %%
print("1.Men\n2.Women")
gender = input("Enter gender:")
age = input("Enter an age:")
age=float(age)
if age>=18:
        print("can apply for vote.")
if age>=18 and age<=60:
        print("can apply for driving license")

if gender=="1":
    if age>=5:
        print("can got to movie.")
    if age>=23:
        print("can get marriged.")
    if age>=18 and age<=32:
        print("can apply for govt jobs.")
else:
    if age>=7:
        print("can got to movie.")
    if age>=18:
        print("can apply for vote.")
    if age>=21:
        print("can get marriged.")
    if age>=18 and age<=34:
        print("can apply for govt jobs.")
# Out:
# 1.Men
# 2.Women
# Enter gender: 1
# Enter an age: 26
# can apply for vote.
# can apply for driving license
# can got to movie.
# can get marriged.
# can apply for govt jobs.
